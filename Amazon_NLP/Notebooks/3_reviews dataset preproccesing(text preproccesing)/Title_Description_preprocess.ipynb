# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Sentimnal_file.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371 entries, 0 to 1370
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1371 non-null   int64
#  1   Title          1371 non-null   object
#  2   Description    1371 non-null   object
#  3   compound_desc  1371 non-null   float64
#  4   compound_titl  1371 non-null   float64
#  5   compound_avg   1371 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 64.4+ KB

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string

# %%
# Load NLTK resources
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Convert text to lowercase
df['Title'] = df['Title'].str.lower()
df['Description'] = df['Description'].str.lower()

# %%
# Tokenization
df['Title'] = df['Title'].apply(word_tokenize)
df['Description'] = df['Description'].apply(word_tokenize)

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0                                         [warranty]
# 1           1  [it, came, with, the, ubuntu, version, ,, not,...
# 2           2  [does, not, come, with, windows, 10, pro, as, ...
# 3           3  [is, the, device, new, in, its, box, or, impor...
# 4           4  [is, the, product, new, ?, arabic, letters, ke...
#
#                                          Description  compound_desc  \
# 0  [warranty, for, only, 6, months, and, the, ven...         0.0000
# 1               [a, good, laptop, for, office, work]         0.4404
# 2  [the, laptop, does, n't, come, with, operating...         0.0000
# 3  [need, to, know, whether, the, device, is, new...         0.0000
# 4            [you, have, n't, bought, anything, yet]         0.0000
#
#    compound_titl  compound_avg
# 0            0.0        0.0000
# 1            0.0        0.2202
# 2            0.0        0.0000
# 3            0.0        0.0000
# ...

# %%
# Remove non-alphabetic characters and numerical digits
df['Title'] = df['Title'].apply(lambda tokens: [word for word in tokens if word.isalpha()])
df['Description'] = df['Description'].apply(lambda tokens: [word for word in tokens if word.isalpha()])

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0                                         [warranty]
# 1           1  [it, came, with, the, ubuntu, version, not, wi...
# 2           2  [does, not, come, with, windows, pro, as, adve...
# 3           3  [is, the, device, new, in, its, box, or, impor...
# 4           4  [is, the, product, new, arabic, letters, keybo...
#
#                                          Description  compound_desc  \
# 0  [warranty, for, only, months, and, the, vendor...         0.0000
# 1               [a, good, laptop, for, office, work]         0.4404
# 2  [the, laptop, does, come, with, operating, sys...         0.0000
# 3  [need, to, know, whether, the, device, is, new...         0.0000
# 4                 [you, have, bought, anything, yet]         0.0000
#
#    compound_titl  compound_avg
# 0            0.0        0.0000
# 1            0.0        0.2202
# 2            0.0        0.0000
# 3            0.0        0.0000
# ...

# %%
# Remove common words
stop_words = set(stopwords.words('english'))
df['Title'] = df['Title'].apply(lambda tokens: [word for word in tokens if word not in stop_words])
df['Description'] = df['Description'].apply(lambda tokens: [word for word in tokens if word not in stop_words])

# %%
df.head()
# Out:
#    Unnamed: 0                                      Title  \
# 0           0                                 [warranty]
# 1           1           [came, ubuntu, version, windows]
# 2           2           [come, windows, pro, advertised]
# 3           3               [device, new, box, imported]
# 4           4  [product, new, arabic, letters, keyboard]
#
#                                          Description  compound_desc  \
# 0       [warranty, months, vendor, provide, invoice]         0.0000
# 1                       [good, laptop, office, work]         0.4404
# 2  [laptop, come, operating, system, windows, pro...         0.0000
# 3       [need, know, whether, device, new, imported]         0.0000
# 4                            [bought, anything, yet]         0.0000
#
#    compound_titl  compound_avg
# 0            0.0        0.0000
# 1            0.0        0.2202
# 2            0.0        0.0000
# 3            0.0        0.0000
# 4            0.0        0.0000

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
df['Title'] = df['Title'].apply(lambda tokens: [lemmatizer.lemmatize(word) for word in tokens])
df['Description'] = df['Description'].apply(lambda tokens: [lemmatizer.lemmatize(word) for word in tokens])

# %%
df.head()
# Out:
#    Unnamed: 0                                     Title  \
# 0           0                                [warranty]
# 1           1           [came, ubuntu, version, window]
# 2           2           [come, window, pro, advertised]
# 3           3              [device, new, box, imported]
# 4           4  [product, new, arabic, letter, keyboard]
#
#                                          Description  compound_desc  \
# 0        [warranty, month, vendor, provide, invoice]         0.0000
# 1                       [good, laptop, office, work]         0.4404
# 2  [laptop, come, operating, system, window, pro,...         0.0000
# 3       [need, know, whether, device, new, imported]         0.0000
# 4                            [bought, anything, yet]         0.0000
#
#    compound_titl  compound_avg
# 0            0.0        0.0000
# 1            0.0        0.2202
# 2            0.0        0.0000
# 3            0.0        0.0000
# 4            0.0        0.0000

# %%
# Stemming
#stemmer = PorterStemmer()
#df['Title'] = df['Title'].apply(lambda tokens: [stemmer.stem(word) for word in tokens])
#df['Description'] = df['Description'].apply(lambda tokens: [stemmer.stem(word) for word in tokens])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Title            0
# Description      0
# compound_desc    0
# compound_titl    0
# compound_avg     0
# dtype: int64
