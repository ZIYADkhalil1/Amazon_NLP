# %%
import pandas as pd

# %%
df1 = pd.read_csv('df1')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 59
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 60 non-null     object
#  1   link                  60 non-null     object
#  2   manifacture           60 non-null     object
#  3   price                 60 non-null     int64
#  4   discount              60 non-null     int64
#  5   availability          60 non-null     int64
#  6   rating                22 non-null     float64
#  7   number_of_rating      60 non-null     int64
#  8   description           60 non-null     object
#  9   Department            60 non-null     object
#  10  Brand Name            60 non-null     object
#  11  Model Name            60 non-null     object
#  12  Screen Size           60 non-null     object
#  13  Color                 60 non-null     object
#  14  Hard Disk Size        60 non-null     object
# ...

# %% [markdown]
# ## preprocessing each column

# %% [markdown]
# #### Brand Name

# %%
df1['Brand Name'].unique()
# Out:
# array(['Lenovo', 'Itel', 'LENOVO', 'DELL', 'Acer', 'Asus', 'ASUS', 'ديل',
#        'HP', 'HUAWEI', 'Dell', 'اسوس'], dtype=object)

# %%
df1['Brand Name'] = df1['Brand Name'].str.replace('ديل', 'Dell')
df1['Brand Name'] = df1['Brand Name'].str.replace('LENOVO', 'Lenovo')
df1['Brand Name'] = df1['Brand Name'].str.replace('ASUS', 'Asus')
df1['Brand Name'] = df1['Brand Name'].str.replace('اسوس', 'Asus')
df1['Brand Name'] = df1['Brand Name'].str.replace('DELL', 'Dell')

# %%
df1['Brand Name'].unique()
# Out:
# array(['Lenovo', 'Itel', 'Dell', 'Acer', 'Asus', 'HP', 'HUAWEI'],
#       dtype=object)

# %% [markdown]
# #### Model Name

# %%
df1['Model Name'].unique().tolist()
# Out:
# ['TB-X306',
#  'itel 15',
#  'V15 - I3-10110U8G1TFHD',
#  'V15 - 82NB0015ED',
#  'Vostro 3510 i3 12G 256 ub',
#  'Lenovo V15 G2 5500U 8G 512G',
#  'IdeaPad 3 15ALC6',
#  'Lenovo IdeaPad 3 - 5700U 8G 512G GRY',
#  'A515-45G-R23H',
#  'X515EP-BQ8G5W',
#  'Lenovo IdeaPad 3 - 82KU00WCAK',
#  'ASUS Vivobook 16X D1603QA-FP005W',
#  'D1603QA-MB007W',
#  'فوسترو 3510 i51035G1 16G 1T 256 UB',
#  '13-bb0003ne',
#  'S433EQ-AM07GW',
#  'IdeaPad 5 15ITL05 - 82FG00WMED',
#  '82K600BMED',
#  'IdeaPad 5',
#  'HUAWEI MateBook B3',
#  'IdeaPad Gaming 3 15ACH6 - 82K201XCUS',
#  'G15-5515 R5 600H 8G 512G RTX3050 WIN11',
#  'IdeaPad Flex 5 14ITL05 - 82HS00QWCC',
#  'IdeaPad Flex 5 14ITL05 i5-1135G7 8G 256G W11',
#  'Legion',
#  '600N2EA',
#  'ThinkPad L13 Yoga Gen 2 - 20VLS20600',
#  'G15-5511 I511260h8g512g3050ub',
#  'IdeaPad Gaming 3 15ACH6 - 5800H16G512G3060DOS',
#  'IdeaPad Gaming 3 15ACH6 - 82K2020BAX',
#  'Lenovo ThinkPad E15 Gen 4',
#  'UX3402ZA-OLED005W',
# ...

# %%
i1 = ['V15 - I3-10110U8G1TFHD','V15 - 82NB0015ED']#V15
i2 = ['Vostro 3510 i3 12G 256 ub','فوسترو 3510 i51035G1 16G 1T 256 UB','Lenovo V15 G2 5500U 8G 512G']#Vostro
i3 = ['IdeaPad 3 15ALC6','Lenovo IdeaPad 3 - 82KU00WCAK','Lenovo IdeaPad 3 - 5700U 8G 512G GRY']#IdeaPad 3
i4 = ['ASUS Vivobook 16X D1603QA-FP005W','D1603QA-MB007W','S433EQ-AM07GW','X515EP-BQ8G5W']#ASUS Vivobook
i5 = ['13-bb0003ne','600N2EA']#hp pavillion
i6 = ['IdeaPad 5 15ITL05' , '82FG00WMED','IdeaPad 5','82HU00VCED','IdeaPad 5 15ITL05 - 82FG00WMED']#IdeaPad 5
i7 = ['82K100F6ED','IdeaPad Gaming 3 15ACH6 - 5800H16G512G3060DOS','IdeaPad Gaming 3 15ACH6 - 82K2020BAX','Lenovo IdeaPad Gaming 3 - 82K200QCAX'
     ,'IdeaPad Gaming 3 15ACH6 - 82K201XCUS','IdeaPad Gaming 3 15ACH6 82K201XKAX']#IdeaPad gaming 3
i8 = ['IdeaPad Flex 5 14ITL05 - 82HS00QWCC','IdeaPad Flex 5 14ITL05 i5-1135G7 8G 256G W11',]#IdeaPad Flex 5
i9 = ['Legion 5 15ACH6H 82JU00B0AX','Legion 5 15IAH7 - 82RC00DEAX','Legion 5 15ACH6H 82JU01BEAX',
    'Legion 5 15IAH7 - 82RC00DLAK','Legion 5 15IAH7H - 82RB00T2AK','Legion','Legion 5 Pro 16ITH6H - 82JD00DTED', 'Legion 5 Pro - 82JD00DTED',
     '82K600BMED', ]#Legion
i10 = ['G15-5515 R5 600H 8G 512G RTX3050 WIN11','G15-5511 I511260h8g512g3050ub','G15-5511 I7-11800H 16G 512G 3050 U','G15-5511 I711800h16g512g3060ub',
 'Dell G15 5511',  'G15 5530 I7-13650HX 16G 512G RTX4060 165Hz W11'   ]
i11 = ['ThinkPad L13 Yoga Gen 2 - 20VLS20600','Lenovo ThinkPad E15 Gen 4', 'UX3402ZA-OLED005W',
       'ThinkPad L13 Yoga Gen 2 I5-1135G7 16G 512G W10P','Yoga Slim 7 Pro 14ACH5 OD','Yoga','Lenovo LOQ 15IRH8 - 82XV00KKAX']#Thinkpad
i12 = ['H5600QM-OLED009W', 'G533ZX-LN060W','90NR09Q3-M009V0','FX517ZC-HN002W','روج'] #asus gaming

# %%
df1['Model Name'] = df1['Model Name'].replace(i1, 'V15')
df1['Model Name'] = df1['Model Name'].replace(i2, 'Vostro')
df1['Model Name'] = df1['Model Name'].replace(i3, 'Ideapad 3')
df1['Model Name'] = df1['Model Name'].replace(i4, 'ASUS Vivobook')
df1['Model Name'] = df1['Model Name'].replace(i5, 'pavillion')
df1['Model Name'] = df1['Model Name'].replace(i6, 'IdeaPad 5')
df1['Model Name'] = df1['Model Name'].replace(i7, 'IdeaPad gaming 3')
df1['Model Name'] = df1['Model Name'].replace(i8, 'IdeaPad Flex 5')
df1['Model Name'] = df1['Model Name'].replace(i9, 'Legion')
df1['Model Name'] = df1['Model Name'].replace(i10, 'G15')
df1['Model Name'] = df1['Model Name'].replace(i11, 'Thinkpad')
df1['Model Name'] = df1['Model Name'].replace(i12, 'Asus gaming')

# %%
df1['Model Name'].unique()
# Out:
# array(['TB-X306', 'itel 15', 'V15', 'Vostro', 'Ideapad 3',
#        'A515-45G-R23H', 'ASUS Vivobook', 'pavillion', 'IdeaPad 5',
#        'Legion', 'HUAWEI MateBook B3', 'IdeaPad gaming 3', 'G15',
#        'IdeaPad Flex 5', 'Thinkpad', 'Asus gaming',
#        'HP Victus 16-d0007ne', 'IdeaPad'], dtype=object)

# %%
df1['Model Name'] = df1['Model Name'].replace(('Ideapad 3', 'Ideapad 5', 'Ideapad'), 'Ideapad')
df1['Model Name'] = df1['Model Name'].replace(('Legion ','Legion 5'), 'Legion')

# %%
df1['Model Name'].unique()
# Out:
# array(['TB-X306', 'itel 15', 'V15', 'Vostro', 'Ideapad', 'A515-45G-R23H',
#        'ASUS Vivobook', 'pavillion', 'IdeaPad 5', 'Legion',
#        'HUAWEI MateBook B3', 'IdeaPad gaming 3', 'G15', 'IdeaPad Flex 5',
#        'Thinkpad', 'Asus gaming', 'HP Victus 16-d0007ne', 'IdeaPad'],
#       dtype=object)

# %%
df1['Model Name'] = df1['Model Name'].replace(('IdeaPad ','IdeaPad Flex 5'), 'Legion')

# %%
df1['Model Name'].unique()
# Out:
# array(['TB-X306', 'itel 15', 'V15', 'Vostro', 'Ideapad', 'A515-45G-R23H',
#        'ASUS Vivobook', 'pavillion', 'IdeaPad 5', 'Legion',
#        'HUAWEI MateBook B3', 'IdeaPad gaming 3', 'G15', 'Thinkpad',
#        'Asus gaming', 'HP Victus 16-d0007ne', 'IdeaPad'], dtype=object)

# %%
df1['Model Name'] = df1['Model Name'].replace(('IdeaPad ','Ideap'), 'Ideapad')

# %% [markdown]
# #### screen size

# %%
df1['Screen Size'].unique()
# Out:
# array(['10.1 Inches', '15.6 Inches', '15.6', '16', '15,6 بوصة',
#        '33.8 Centimeters', '14 Inches', '16 Inches', '13.3 Inches',
#        '15 Inches', '14 بوصة', '17 Inches'], dtype=object)

# %%
df1['Screen Size'] =df1['Screen Size'].replace(('15.6 Inches','15.6','15,6 بوصة','33.8 Centimeters','16 Inches','15 Inches' ),'15.6')

# %%
df1['Screen Size'].unique()
# Out:
# array(['10.1 Inches', '15.6', '16', '14 Inches', '13.3 Inches', '14 بوصة',
#        '17 Inches'], dtype=object)

# %%
df1['Screen Size'] =df1['Screen Size'].replace(('14 Inches', '13.3 Inches', '14 بوصة'),'13.3')

# %%
df1['Screen Size'] = df1['Screen Size'].str.replace('Inches', '')

# %%
df1['Screen Size'].unique()
# Out:
# array(['10.1 ', '15.6', '16', '13.3', '17 '], dtype=object)

# %%
df1['Screen Size'] = df1['Screen Size'].astype(float)

# %% [markdown]
# #### Color

# %%
df1['Color'].unique()
# Out:
# array(['Gray', 'Silver', 'Grey', 'Black', 'Transparent Silver', 'أسود',
#        'Phantom Grey', 'Graphite Grey', 'Shadow Black',
#        'Phantom Blue (Top), Shadow Black (Bottom)', 'Dark Shadow Grey',
#        'Onyx Grey', 'Storm Grey', 'Phantom Blue',
#        'Dark Shadow Gray with Black thermal shelf', 'STINGRAY'],
#       dtype=object)

# %%
df1['Color'] = df1['Color'].replace(('Gray','Silver', 'Grey','Transparent Silver', 'Phantom Grey', 'Graphite Grey',
'Dark Shadow Grey','Onyx Grey', 'Storm Grey','STINGRAY'),'Gray')
df1['Color'] = df1['Color'].replace(('Black','أسود','Shadow Black','Shadow Black (Bottom)', 'Dark Shadow Gray with Black thermal shelf'),'Black')
df1['Color'] = df1['Color'].replace(('Phantom Blue (Top), Shadow Black (Bottom)','Phantom Blue'),'Blue')

# %%
df1['Color'].unique()
# Out:
# array(['Gray', 'Black', 'Blue'], dtype=object)

# %% [markdown]
# #### Hard Disk Size

# %%
df1['Hard Disk Size'].unique().tolist()
# Out:
# ['32', '256', '1024', '512', '1256']

# %%
df1['Hard Disk Size'] = df1['Hard Disk Size'].str.replace('32 ','32')

# %%
df1['Hard Disk Size'] = df1['Hard Disk Size'].astype(int)

# %% [markdown]
# #### RAM Memory Installed

# %%
df1['RAM Memory Installed'].unique()
# Out:
# array(['2 ', '8 ', '4 ', '12 ', '16 ', '17 ', '16', '32 '], dtype=object)

# %%
df1['RAM Memory Installed'] = df1['RAM Memory Installed'].str.replace('غيغابايت','')

# %%
df1['RAM Memory Installed'] = df1['RAM Memory Installed'].astype(int)

# %% [markdown]
# #### Operating System

# %%
df1['Operating System'].unique()
# Out:
# array(['Android', 'Windows', 'DOS', 'UBUNTU', 'Linux'], dtype=object)

# %%
df1['Operating System'] = df1['Operating System'].replace(('Windows 10', 'Windows 10 Pro','Windows 10 Home','Windows 11 Home', 'Windows 11' ),'Windows')

# %% [markdown]
# #### Graphics Description

# %%
df1['Graphics Description'].unique()
# Out:
# array(['Integrated', 'Dedicated'], dtype=object)

# %% [markdown]
# #### Resolution

# %%
df1['Resolution'].unique()
# Out:
# array(['800', '1080'], dtype=object)

# %%
df1['Resolution'] = df1['Resolution'].replace(('1080p', '1920x1080', '1920 x 1080'),'1080')

# %%
df1['Resolution'] = df1['Resolution'].str.replace('1280 x 800', '800')

# %% [markdown]
# #### CPU Model

# %%
df1['CPU Model'].unique()
# Out:
# array(['Intel Core i7', 'Core i3-9300T', 'Intel Core i3',
#        'AMD Ryzen 5 5500U', 'AMD Ryzen 7 5700U',
#        'Ryzen Threadripper 1920X', 'Core i5', 'Ryzen 5', 'Ryzen 7',
#        'Intel Core i5', 'Core i5 Family', 'Core i7 3537U',
#        'Intel Core i7-1165G7', 'Core i7', 'Core i5-11500',
#        'Ryzen 5 5600H', 'Intel Core i5-1135G7', 'Core i7-1185G7E',
#        'Ryzen 7 5800H', 'Core i7-12650H', 'Core i7 Family', 'R12000',
#        'Core i7-660UM', 'Intel Core i9-11900F'], dtype=object)

# %%
df1['CPU Model'] = df1['CPU Model'].replace(('Intel Core i7','Core i7 3537U','Intel Core i7-1165G7', 'Core i7','Core i7-1185G7E',
'Core i7-12650H', 'Core i7-660UM','Core i7 Family'),'Intel Core i7 Family')

# %%
df1['CPU Model'].unique()
# Out:
# array(['Intel Core i7 Family', 'AMD Ryzen 5', 'AMD Ryzen 7',
#        'Ryzen Threadripper 1920X', 'Intel Core i5 Family',
#        'Intel Core i9-11900F'], dtype=object)

# %%
df1['CPU Model'] = df1['CPU Model'].replace(('Core i3-9300T', 'Intel Core i3'),'Intel Core i3 Family')

# %%
df1['CPU Model'] = df1['CPU Model'].replace(('Core i5','Intel Core i5', 'Core i5 Family', 'Core i5-11500','Intel Core i5-1135G7'),'Intel Core i5 Family' )

# %%
df1['CPU Model'] = df1['CPU Model'].replace(('AMD Ryzen 5 5500U','Ryzen 5','Ryzen 5 5600H'),'AMD Ryzen 5',)

# %%
df1['CPU Model'] = df1['CPU Model'].replace(('AMD Ryzen 7 5700U','Ryzen 7',
       'Ryzen 7 5800H', 'R12000'),'AMD Ryzen 7',)

# %%
df1
# Out:
#                                                 title  \
# 0       Lenovo TB-X306 LPDDR4X 2GB, 32GB (ZA6V0038EG)
# 1   itel 15.6 inch,FHD,Core-i3 1115G4,4GB+256GB SS...
# 2   Lenovo V15 Laptop - Intel Core i3-10110U, 8GB ...
# 3   Lenovo V15 Laptop - Intel Core i3-10110U, 4GB ...
# 4   Dell Vostro 3510 laptop - 11th Intel core i3-1...
# 5   Lenovo V15 G2 Laptop - Ryzen 5 5500U 6-Cores, ...
# 6   Lenovo IdeaPad 3 15ALC6 Laptop, R5-5500U, 8GB,...
# 7   Lenovo IdeaPad 3 15ALC6 Laptop - Ryzen 7 5700U...
# 8   ACER ASPIRE5- AMD RYZEN7-5700U- 1024 SSD- 16 G...
# 9   ASUS Laptop X515EP-BQ8G5W (11th Generation Int...
# 10  Lenovo IdeaPad 3 15ALC6 Laptop - Ryzen 7 5700U...
# 11  ASUS Vivobook 16X D1603QA-FP005W Ryzen™ 5 5600...
# 12  Asus Vivobook D1603QA-MB007W(Ryzen7 5800H - Ra...
# 13  لاب توب ديل فوسترو 3510 انتل كور i5-1035G1 و16...
# 14                     HP Pavilion Laptop 13-bb0003ne
# 15  ASUS VivoBook S14 S433EQ-AM07GW i7-1165G7 MX35...
# ...

# %%
df1.to_csv('df1',index_label=False)
